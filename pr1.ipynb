# %%
x = 5
y = 5.5
name = "ansh"
b = True
print("data-type of variable x is " , type(x))
print("data-type of variable y is " , type(y))
print("data-type of variable name is " , type(name))
print("data-type of variable b is " , type(b))
# Out:
# Enter value of x :6
# data-type of variable x is  <class 'str'>
# data-type of variable y is  <class 'float'>
# data-type of variable name is  <class 'str'>
# data-type of variable b is  <class 'bool'>

# %%
x = int(input("Enter value of x : "))
y = int(input("Enter value of y : "))
print("addition of" , x , "and" , y , "is" , x+y)
print("subtraction of" , x ,"and" , y , "is" , x - y)
print("division of", x , "and" , y ,"is",y / x)
print("multiplication of" , x , "and", y ,"is",x * y)
print("mod of", x , "and" , y ,"is",x % y)
print("power operater : ", pow(x,3))
print("flor divisor :",x//y)
# Out:
# Enter value of x : 5
# Enter value of y : 5
# addition of 5 and 5 is 10
# subtraction of 5 and 5 is 0
# division of 5 and 5 is 1.0
# multiplication of 5 and 5 is 25
# mod of 5 and 5 is 0
# power operater :  125
# flor divisor : 1

# %%
x = int(input("Enter value of x : "))
y = int(input("Enter value of y : "))
print(x , "is greater than to" , y , "->" ,  x > y)
print(x , "is less thasn to" , y , "->" , x < y)
print(x , "is equal to", y , "->" ,x == y)
print(x , "is not equal to" , y , "->" , x != y)
print(x , "is greater than or equal to" , y , "->" , x >= y)
print(x , "is less then or equal to" , y , "->" , x <= y)
# Out:
# Enter value of x : 10
# Enter value of y : 20
# 10 is greater than to 20 -> False
# 10 is less thasn to 20 -> True
# 10 is equal to 20 -> False
# 10 is not equal to 20 -> True
# 10 is greater than or equal to 20 -> False
# 10 is less then or equal to 20 -> True

# %%
x = int(input("Enter value of x : "))
print("x > 10 and x < 20 =>" , x > 10 and x < 20)
print("x < 10 or x == 15 =>",x < 10 or x == 15)
print("not(x == 15) =>",not (x == 15))
# Out:
# Enter value of x : 15
# x > 10 and x < 20 => True
# x < 10 or x == 15 => True
# not(x ==15) => False

# %%
x = int(input("Enter value of x : "))
y = int(input("Enter value of y : "))
x += y
print("x += y => x is",x , "and y is" , y)
x -= y
print("x -= y => x is",x , "and y is" , y)
x *= y
print("x *= y => x is",x , "and y is" , y)
x /= y
print("x /= y => x is",x , "and y is" , y)
x %= y
print("x %= y => x is",x , "and y is" , y)
x //= y
print("x //= y => x is",x , "and y is" , y)
x **= y
print("x **= y => x is",x , "and y is" , y)
# Out:
# Enter value of x : 5
# Enter value of y : 5
# x += y => x is 10 and y is 5
# x -= y => x is 5 and y is 5
# x *= y => x is 25 and y is 5
# x /= y => x is 5.0 and y is 5
# x %= y => x is 0.0 and y is 5
# x //= y => x is 0.0 and y is 5
# x **= y => x is 0.0 and y is 5

# %%
x = int(input("Enter value of x : "))
y = int(input("Enter value of y : "))
print("x & y =>",x & y)
print("x | y =>",x | y)
print("x ^ y =>",x ^ y)
print("~x =>",~x)
print("x << 2 =>",x << 2)
print("x >> 2 =>",x >> 2)
# Out:
# Enter value of x : 5
# Enter value of y : 5
# x & y => 5
# x | y => 5
# x ^ y => 0
# ~x => -6
# x << 2 => 20
# x >> 2 => 1

# %%
list1 = [10,20,30]
print("list1 is",list1)
print("10 in list1 =>", 10 in list1)
print("40 in list1 =>", 40 in list1)
print("10 not in list1 =>", 10 not in list1)
print("40 not in list1 =>", 40 not in list1)
# Out:
# list1 is [10, 20, 30]
# 10 in list1 => True
# 40 in list1 => False
# 10 not in list1 => False
# 40 not in list1 => True

# %%
x = 10
y = 20
a = id(x)
b = id(y)
print(a is b)
print(a is not b)
# Out:
# False
# True

# %%
x = input("Enter value of x : ")
print("value of x : ",x)
x = int(x) # int(input("Enter valuer of x : "))
print("data-type of variable : " , type(x))
# Out:
# Enter value of x : 5
# value of x :  5
# data-type of variable :  <class 'int'>

# %%
print(3*x)
# Out:
# 12

# %%
x = float(input("Enter amount : "))
print("rupees :" ,int(x))
y = (x - int(x)) *100
print("paise : ", y)
# Out:
# rupees : 20
# paise :  50.0

# %%
print("hello world")
# Out:
# hello world
